# %%
import os
import biom
from biom import Table
import pandas as pd
import numpy as np

# %%
metadata = pd.read_excel("../../data/metadata.xls")

# %%
metadata.head()
# Out:
#           Run        study subject_id treatment   group1   group2  group  \
# 0  SRR6444565  PRJNA428736       U222   control  Control  Control    0.0
# 1  SRR6443884  PRJNA428736       U222   control  Control  Control    0.0
# 2  SRR6444382  PRJNA428736       U222   control  Control  Control    0.0
# 3  SRR6443860  PRJNA428736       U222   control  Control  Control    0.0
# 4  SRR6444083  PRJNA428736       U222   control  Control  Control    0.0
#
#              timepoint timepoint_numeric timepoint_id   fber_type fber_amount  \
# 0  2016-09-01 00:00:00                 0       U222_0  accessible         NaN
# 1  2016-09-01 00:00:00                 0       U222_0  accessible         NaN
# 2  2016-09-01 00:00:00                 0       U222_0  accessible         NaN
# 3  2016-10-01 00:00:00                 1       U222_1  accessible         NaN
# 4  2016-10-01 00:00:00                 1       U222_1  accessible         NaN
#
#   time_days    age  sex  bmi  \
# 0         0  17-29  NaN  NaN
# 1         0  17-29  NaN  NaN
# 2         0  17-29  NaN  NaN
# 3        14  17-29  NaN  NaN
# 4        14  17-29  NaN  NaN
#
#                                         PCR_primers Region        Platform  \
# 0  FWD:GTGCCAGCMGCCGCGGTAA;REV:GGACTACHVGGGTWTCTAAT     V4  Illumina MiSeq
# 1  FWD:GTGCCAGCMGCCGCGGTAA;REV:GGACTACHVGGGTWTCTAAT     V4  Illumina MiSeq
# 2  FWD:GTGCCAGCMGCCGCGGTAA;REV:GGACTACHVGGGTWTCTAAT     V4  Illumina MiSeq
# 3  FWD:GTGCCAGCMGCCGCGGTAA;REV:GGACTACHVGGGTWTCTAAT     V4  Illumina MiSeq
# 4  FWD:GTGCCAGCMGCCGCGGTAA;REV:GGACTACHVGGGTWTCTAAT     V4  Illumina MiSeq
#
#          Country
# 0  North America
# 1  North America
# 2  North America
# 3  North America
# 4  North America

# %%
study = metadata.study.unique()

# %%
study
# Out:
# array(['PRJNA428736', 'PRJNA780023', 'PRJNA560950', 'PRJEB2165',
#        'PRJNA293971', 'PRJNA306884', 'PRJNA385004', 'PRJNA891951',
#        'PRJEB41443'], dtype=object)

# %%
for i in study:
    df = metadata.loc[metadata.study.values == i]
    dir_path = "/home/dongbiao/word_embedding_microbiome/programe_test/dietary_fber/data/projects"
    os.makedirs(f"{dir_path}/{i}", exist_ok=True)
    df["Run"].to_csv(f"{dir_path}/{i}/sample.txt", index=False, header=False)

# %%
n = 1 
for name in study:
    if n == 1:
        table = biom.load_table(f"/home/dongbiao/word_embedding_microbiome/programe_test/dietary_fber/data/projects/{name}/results/extracted-feature-table/feature-table.biom")
        reads_depth = table.sum(axis="sample")
        sid = table.ids(axis="sample")
        table.filter(sid[reads_depth > 1000], axis='sample')
        table.remove_empty()
        fid = table.ids(axis="observation")
        prevalence = table.nonzero_counts(axis="observation")
        table.filter(fid[prevalence > 5], axis="observation")
        table.remove_empty()
    else:
        temp = biom.load_table(f"/home/dongbiao/word_embedding_microbiome/programe_test/dietary_fber/data/projects/{name}/results/extracted-feature-table/feature-table.biom")
        reads_depth = temp.sum(axis="sample")
        sid = temp.ids(axis="sample")
        temp.filter(sid[reads_depth > 1000], axis='sample')
        temp.remove_empty()
        fid = temp.ids(axis="observation")
        prevalence = temp.nonzero_counts(axis="observation")
        temp.filter(fid[prevalence > 5], axis="observation")
        
        table = table.merge(temp)
    n = n + 1
table.remove_empty()
# Out:
# 3723 x 2379 <class 'biom.table.Table'> with 297924 nonzero entries (3% dense)

# %%
reads_depth = table.sum(axis="sample")
sid = table.ids(axis="sample")
table.filter(sid[reads_depth > 1000], axis='sample')
table.remove_empty()
# Out:
# 3723 x 2348 <class 'biom.table.Table'> with 297853 nonzero entries (3% dense)

# %%
with biom.util.biom_open(f"/home/dongbiao/word_embedding_microbiome/programe_test/dietary_fber/data/projects/table_{table.shape[0]}_{table.shape[1]}.biom", 'w') as f:
    table.to_hdf5(f, 'example')

# %%
table
# Out:
# 3723 x 2348 <class 'biom.table.Table'> with 297853 nonzero entries (3% dense)

# %%
sid = metadata.loc[metadata.study.values == ""]
